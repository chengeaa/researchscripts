# %%
#imports 
import numpy as np
import pandas as pd
from scipy.special import factorial
import matplotlib.pyplot as plt
from pathlib import Path
# plt.rcParams["figure.figsize"] = (20,7)
# plt.rcParams["font.size"] = 12
# %matplotlib inline

# %%
from energydiagram import ED
# plt.figure(figsize = (10,10))
diagram = ED(linewidth = 4)
diagram.add_level(0, top_text = '')
diagram.add_level(-0.2,'(a)')
diagram.add_level(.77,'(b)')
diagram.add_level(-.08,'(c)')
diagram.add_level(-.79,'(d)')
diagram.add_link(0, 1)
diagram.add_link(1, 2)
diagram.add_link(2, 3)
diagram.add_link(3, 4)

fig, ax = diagram.plot()

ax.arrow(1, -.5, 0, 1, head_width = 0.05, color = 'k')
# plt.savefig("energies.png", dpi = 900)
